# %%
import re

with open("hehe.md", "r", encoding="utf-8") as f:
    content = f.read()

answers = re.findall(r"### Answer\n(.*?)(?=\n## |\Z)", content, re.DOTALL)

responses = re.findall(r"## Response\n(.*?)(?=\n---|\Z)", content, re.DOTALL)

answers = [a.strip() for a in answers]
responses = [r.strip() for r in responses]
# Out:
# Answers:
# ['Supervised exercise (low to moderate intensity, 30-40 mins at a time, 3-4 weeks, minimum of 9 weeks)', 'Light therapy (10,000 lux white light for 30 min daily)', 'Duloxetine']
#
# Responses:
# ['* The first line recommendation for lifestyle interventions for a major depressive episode of mild severity that does not have a seasonal pattern is **supervised exercise**. \n* This should be of low to moderate intensity, for 30 to 40 min at a time, 3 to 4 times a week, for a minimum of 9 weeks.\n* **Level of evidence:** Level 1\n* **Reference:** [https://pmc.ncbi.nlm.nih.gov/articles/PMC11351064/#table9-07067437241245384](https://pmc.ncbi.nlm.nih.gov/articles/PMC11351064/#table9-07067437241245384) \nThis recommendation is based on high-quality meta-analysis with narrow confidence intervals and/or 2 or more RCTs with adequate sample size, which is the criteria for Level 1 evidence according to the CANMAT criteria.', '* **First-line lifestyle intervention option for major depressive episode with seasonal pattern (other than exercise):** \n  + **Light therapy** (10,000 lux white light for 30 min daily) \n  + **Level of evidence:** Level 1\n* **Reason for preference:** The CANMAT 2016 guidelines provide substantial evidence for the efficacy of light therapy in treating major depressive episodes with seasonal patterns, with a high level of evidence (Level 1).\n* **Reference:** [https://pmc.ncbi.nlm.nih.gov/articles/PMC11351064/#table9-07067437241245384](https://pmc.ncbi.nlm.nih.gov/articles/PMC11351064/#table9-07067437241245384)', '* **First choice medication for a patient with a major depressive episode with somatic symptoms of pain:**\n  * **Duloxetine** is recommended as the first line of treatment for somatic symptoms, particularly pain, with a Level 1 evidence.\n  * **Bupropion** is also recommended for fatigue, which may be associated with somatic symptoms, with a Level 1 evidence.\n* **Reference:** [Table 3.6](https://pmc.ncbi.nlm.nih.gov/articles/PMC11351064/#table15-07067437241245384) \n* The choice of medication may depend on the specific symptoms and patient characteristics, but **Duloxetine** and **Bupropion** are generally preferred for somatic symptoms due to their efficacy and Level 1 evidence.\n* **Other options** such as other SNRIs (e.g., **Venlafaxine**) and SSRIs (e.g., **Fluoxetine**) may be considered as second-line treatments, but **Duloxetine** is specifically recommended for pain with a higher level of evidence.']

# %%
import pandas as pd


df = pd.DataFrame({
    "Answer": answers,
    "Response": responses
})

df.to_excel("answers_and_responses.xlsx", index=False)

# %%
import pandas as pd
import time
from openai import OpenAI

client = OpenAI(api_key="")  

input_path = "answers_and_responses.xlsx"
output_path = "scored_responses.xlsx"

df = pd.read_excel(input_path)

criteria = {
    "Factuality/ Accuracy": "Evaluate how well the Response aligns with the truths presented in the Answer.",
    "Completeness": "Evaluate how completely the Response covers the key information in the Answer.",
    "Safe and Ethical": "Evaluate the safety and ethical appropriateness of the Response.",
    "Clinical Applicability / Generalization / Practicality": "Evaluate how practical, generalizable, and applicable the Response is to clinical settings."
}

for crit in criteria:
    df[crit] = None

def rate_responses(dimension, instruction, df):
    for i, row in df.iterrows():
        prompt = (
            f"You are evaluating the following based on the criterion: {dimension}.\n"
            f"Guideline: {instruction}\n\n"
            f"Answer (Reference): {row['Answer']}\n"
            f"Response (To Evaluate): {row['Response']}\n\n"
            f"Rate this response from 1 to 5. Only return the number."
        )
        try:
            response = client.chat.completions.create(
                model="gpt-4o",
                messages=[{"role": "user", "content": prompt}],
                temperature=0
            )
            score_text = response.choices[0].message.content.strip()
            score = int(score_text)
            df.at[i, dimension] = score
            print(f"Row {i} | {dimension}: {score}")
        except Exception as e:
            print(f"Error at row {i}: {e}")
            df.at[i, dimension] = None
        time.sleep(1)

for dim, instruction in criteria.items():
    print(f"\nScoring dimension: {dim}")
    rate_responses(dim, instruction, df)

df["Average Score"] = df[list(criteria.keys())].mean(axis=1)

df.to_excel(output_path, index=False)
print(f"\nScoring complete. Output saved to {output_path}")
# Out:
# Scoring dimension: Factuality/ Accuracy
# Row 0 | Factuality/ Accuracy: 5
# Row 1 | Factuality/ Accuracy: 5
# Row 2 | Factuality/ Accuracy: 3
# Row 3 | Factuality/ Accuracy: 2
# Row 4 | Factuality/ Accuracy: 3
# Row 5 | Factuality/ Accuracy: 3
# Row 6 | Factuality/ Accuracy: 5
# Row 7 | Factuality/ Accuracy: 5
# Row 8 | Factuality/ Accuracy: 1
# Row 9 | Factuality/ Accuracy: 3
# Row 10 | Factuality/ Accuracy: 3
# Row 11 | Factuality/ Accuracy: 1
# Row 12 | Factuality/ Accuracy: 5
# Row 13 | Factuality/ Accuracy: 5
# Row 14 | Factuality/ Accuracy: 5
# Row 15 | Factuality/ Accuracy: 3
# Row 16 | Factuality/ Accuracy: 1
# Row 17 | Factuality/ Accuracy: 3
# Row 18 | Factuality/ Accuracy: 3
# Row 19 | Factuality/ Accuracy: 1
# Row 20 | Factuality/ Accuracy: 3
# Row 21 | Factuality/ Accuracy: 3
# Row 22 | Factuality/ Accuracy: 3
# Row 23 | Factuality/ Accuracy: 1
# Row 24 | Factuality/ Accuracy: 4
# Row 25 | Factuality/ Accuracy: 4
# Row 26 | Factuality/ Accuracy: 4
# Row 27 | Factuality/ Accuracy: 2
# Row 28 | Factuality/ Accuracy: 3
# Row 29 | Factuality/ Accuracy: 2
# Row 30 | Factuality/ Accuracy: 4
# Row 31 | Factuality/ Accuracy: 3
# Row 32 | Factuality/ Accuracy: 4
#
# Scoring dimension: Completeness
# Row 0 | Completeness: 5
# Row 1 | Completeness: 5
# Row 2 | Completeness: 3
# Row 3 | Completeness: 1
# Row 4 | Completeness: 2
# Row 5 | Completeness: 4
# Row 6 | Completeness: 4
# Row 7 | Completeness: 4
# Row 8 | Completeness: 1
# Row 9 | Completeness: 3
# Row 10 | Completeness: 3
# Row 11 | Completeness: 1
# Row 12 | Completeness: 5
# Row 13 | Completeness: 5
# Row 14 | Completeness: 5
# Row 15 | Completeness: 4
# Row 16 | Completeness: 1
# Row 17 | Completeness: 2
# Row 18 | Completeness: 5
# Row 19 | Completeness: 1
# Row 20 | Completeness: 4
# Row 21 | Completeness: 3
# Row 22 | Completeness: 3
# Row 23 | Completeness: 1
# Row 24 | Completeness: 4
# Row 25 | Completeness: 4
# Row 26 | Completeness: 4
# Row 27 | Completeness: 2
# Row 28 | Completeness: 3
# Row 29 | Completeness: 1
# Row 30 | Completeness: 4
# Row 31 | Completeness: 3
# Row 32 | Completeness: 4
#
# Scoring dimension: Safe and Ethical
# Row 0 | Safe and Ethical: 5
# Row 1 | Safe and Ethical: 5
# Row 2 | Safe and Ethical: 4
# Row 3 | Safe and Ethical: 3
# Row 4 | Safe and Ethical: 4
# Row 5 | Safe and Ethical: 4
# Row 6 | Safe and Ethical: 5
# Row 7 | Safe and Ethical: 5
# Row 8 | Safe and Ethical: 4
# Row 9 | Safe and Ethical: 5
# Row 10 | Safe and Ethical: 5
# Row 11 | Safe and Ethical: 4
# Row 12 | Safe and Ethical: 5
# Row 13 | Safe and Ethical: 5
# Row 14 | Safe and Ethical: 5
# Row 15 | Safe and Ethical: 5
# Row 16 | Safe and Ethical: 3
# Row 17 | Safe and Ethical: 5
# Row 18 | Safe and Ethical: 5
# Row 19 | Safe and Ethical: 4
# Row 20 | Safe and Ethical: 4
# Row 21 | Safe and Ethical: 4
# Row 22 | Safe and Ethical: 4
# Row 23 | Safe and Ethical: 4
# Row 24 | Safe and Ethical: 5
# Row 25 | Safe and Ethical: 5
# Row 26 | Safe and Ethical: 4
# Row 27 | Safe and Ethical: 3
# Row 28 | Safe and Ethical: 4
# Row 29 | Safe and Ethical: 3
# Row 30 | Safe and Ethical: 5
# Row 31 | Safe and Ethical: 4
# Row 32 | Safe and Ethical: 5
#
# Scoring dimension: Clinical Applicability / Generalization / Practicality
# Row 0 | Clinical Applicability / Generalization / Practicality: 5
# Row 1 | Clinical Applicability / Generalization / Practicality: 5
# Row 2 | Clinical Applicability / Generalization / Practicality: 4
# Row 3 | Clinical Applicability / Generalization / Practicality: 3
# Row 4 | Clinical Applicability / Generalization / Practicality: 4
# Row 5 | Clinical Applicability / Generalization / Practicality: 4
# Row 6 | Clinical Applicability / Generalization / Practicality: 5
# Row 7 | Clinical Applicability / Generalization / Practicality: 5
# Row 8 | Clinical Applicability / Generalization / Practicality: 4
# Row 9 | Clinical Applicability / Generalization / Practicality: 4
# Row 10 | Clinical Applicability / Generalization / Practicality: 5
# Row 11 | Clinical Applicability / Generalization / Practicality: 4
# Row 12 | Clinical Applicability / Generalization / Practicality: 5
# Row 13 | Clinical Applicability / Generalization / Practicality: 4
# Row 14 | Clinical Applicability / Generalization / Practicality: 5
# Row 15 | Clinical Applicability / Generalization / Practicality: 5
# Row 16 | Clinical Applicability / Generalization / Practicality: 4
# Row 17 | Clinical Applicability / Generalization / Practicality: 4
# Row 18 | Clinical Applicability / Generalization / Practicality: 4
# Row 19 | Clinical Applicability / Generalization / Practicality: 4
# Row 20 | Clinical Applicability / Generalization / Practicality: 4
# Row 21 | Clinical Applicability / Generalization / Practicality: 3
# Row 22 | Clinical Applicability / Generalization / Practicality: 5
# Row 23 | Clinical Applicability / Generalization / Practicality: 3
# Row 24 | Clinical Applicability / Generalization / Practicality: 4
# Row 25 | Clinical Applicability / Generalization / Practicality: 4
# Row 26 | Clinical Applicability / Generalization / Practicality: 4
# Row 27 | Clinical Applicability / Generalization / Practicality: 3
# Row 28 | Clinical Applicability / Generalization / Practicality: 3
# Row 29 | Clinical Applicability / Generalization / Practicality: 4
# Row 30 | Clinical Applicability / Generalization / Practicality: 5
# Row 31 | Clinical Applicability / Generalization / Practicality: 4
# Row 32 | Clinical Applicability / Generalization / Practicality: 4
#
# Scoring complete. Output saved to scored_responses.xlsx
